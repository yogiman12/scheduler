# %%
import pandas as pd
from  schedual.schedual import *

# %%
df = pd.read_csv("../table alg/collage - ict.csv")
df1 = df[df['Semester'] == 1]

# %%
data = {"dr":{},"dep":{}}
for i in df1['Professor'].unique():
    data['dr'][i]=tuple(df1[df1['Professor']==i]['Course'].unique())
for i in df1['Year'].unique():
    data['dep'][i]=tuple(df1[df1['Year']==i]['Course'].unique())
    # print("-----")

# %%
available_days: dict = {
    'Dr. Alicia Chen':       [1, 3, 5],
    'Dr. Marcus Johnson':    [2, 4, 6],
    'Dr. Emily Wong':        [1, 2, 4],
    'Dr. Robert Taylor':     [3, 5],
    'Dr. Sarah Martinez':    [1, 2, 3],
    'Dr. David Lee':         [2, 4],
    'Dr. Thomas Wilson':     [1, 3, 6],
    'Dr. Rachel Green':      [4, 5, 6],
    'Dr. Jennifer Lopez':    [2, 3, 6],
    'Dr. James White':       [1, 5],
    'Dr. Christopher Davis': [2, 4, 5],
    'Dr. Olivia Clark':      [3, 6],
    'Dr. Lisa Anderson':     [1, 4, 6],
    'Dr. Michael Brown':     [2, 3, 4, 5]
}
_={}
for d , days in available_days.items():
    for _d , cs in data['dr'].items():
        for c in cs:
            if d == _d:
                _[c] = days 
data['available_days'] =_

# %%
courses_hours = {
    'Intro. to Cyber Security': 1,
    'IT Essentials': 2,
    'Technical English 1': 2,
    'Mathematics 1': 2,
    'Physics': 2,
    'Programming Essentials in Python': 2,
    'Linux Essentials': 2,
    'Programming Essentials in C++': 2,
    'Web Programming I': 1,
    'Introduction to DB': 2,
    'Digital Engineering': 2,
    'Operating System': 2,
    'Advanced Programming in C': 2,
    'Data Communication': 2,
    'Java Programming II': 1,
    'Computer Architecture': 2,
    'Microprocessor': 2,
    'Computer Graphics': 2,
    'CCNA R&S II': 2,
    'Network Administration': 2,
    'Mobile Programming II': 1,
    'IoT Architecture & Protocols/IoT Programming': 2,
    'Artificial Intelligence': 2,
    'Windows Programming I': 1,
    'Signal Processing': 2,
    'CCNA R&S IV': 2,
    'CCNA Cybersecurity Operations': 2,
    'Server Administration': 2,
    'Encryption Algorithm': 2
}

# %%
data
# Out:
# {'dr': {'Dr. Alicia Chen': ('Intro. to Cyber Security',
#    'CCNA Cybersecurity Operations',
#    'Encryption Algorithm'),
#   'Dr. Marcus Johnson': ('IT Essentials', 'Windows Programming I'),
#   'Dr. Emily Wong': ('Technical English 1',),
#   'Dr. Robert Taylor': ('Mathematics 1',),
#   'Dr. Sarah Martinez': ('Physics',
#    'Artificial Intelligence',
#    'Signal Processing'),
#   'Dr. David Lee': ('Programming Essentials in Python',
#    'Programming Essentials in C++',
#    'Advanced Programming in C'),
#   'Dr. Thomas Wilson': ('Linux Essentials',
#    'Operating System',
#    'Server Administration'),
#   'Dr. Rachel Green': ('Web Programming I', 'Java Programming II'),
#   'Dr. Jennifer Lopez': ('Introduction to DB',),
#   'Dr. James White': ('Digital Engineering',
#    'Computer Architecture',
#    'Microprocessor'),
#   'Dr. Christopher Davis': ('Data Communication',
#    'CCNA R&S II',
#    'Network Administration',
#    'CCNA R&S IV'),
#   'Dr. Olivia Clark': ('Computer Graphics',),
#   'Dr. Lisa Anderson': ('Mobile Programming II',),
#   'Dr. Michael Brown': ('IoT Architecture & Protocols/IoT Programming',)},
#  'dep': {'1': ('Intro. to Cyber Security',
#    'IT Essentials',
#    'Technical English 1',
#    'Mathematics 1',
#    'Physics',
#    'Programming Essentials in Python'),
#   '2': ('Linux Essentials',
#    'Programming Essentials in C++',
#    'Web Programming I',
#    'Introduction to DB',
#    'Digital Engineering',
#    'Operating System'),
#   '3s': ('Advanced Programming in C',
#    'Data Communication',
#    'Java Programming II',
#    'Computer Architecture',
#    'Microprocessor',
#    'Computer Graphics'),
#   '3n': ('CCNA R&S II',
#    'Java Programming II',
#    'Data Communication',
#    'Network Administration',
#    'Microprocessor',
#    'Computer Architecture'),
#   '4s': ('CCNA R&S II',
#    'Mobile Programming II',
#    'IoT Architecture & Protocols/IoT Programming',
#    'Artificial Intelligence',
#    'Windows Programming I',
#    'Signal Processing'),
#   '4n': ('CCNA R&S IV',
#    'IoT Architecture & Protocols/IoT Programming',
#    'Artificial Intelligence',
#    'CCNA Cybersecurity Operations',
#    'Server Administration',
#    'Encryption Algorithm')},
#  'available_days': {'Intro. to Cyber Security': [1, 3, 5],
#   'CCNA Cybersecurity Operations': [1, 3, 5],
#   'Encryption Algorithm': [1, 3, 5],
#   'IT Essentials': [2, 4, 6],
#   'Windows Programming I': [2, 4, 6],
#   'Technical English 1': [1, 2, 4],
#   'Mathematics 1': [3, 5],
#   'Physics': [1, 2, 3],
#   'Artificial Intelligence': [1, 2, 3],
#   'Signal Processing': [1, 2, 3],
#   'Programming Essentials in Python': [2, 4],
#   'Programming Essentials in C++': [2, 4],
#   'Advanced Programming in C': [2, 4],
#   'Linux Essentials': [1, 3, 6],
#   'Operating System': [1, 3, 6],
#   'Server Administration': [1, 3, 6],
#   'Web Programming I': [4, 5, 6],
#   'Java Programming II': [4, 5, 6],
#   'Introduction to DB': [2, 3, 6],
#   'Digital Engineering': [1, 5],
#   'Computer Architecture': [1, 5],
#   'Microprocessor': [1, 5],
#   'Data Communication': [2, 4, 5],
#   'CCNA R&S II': [2, 4, 5],
#   'Network Administration': [2, 4, 5],
#   'CCNA R&S IV': [2, 4, 5],
#   'Computer Graphics': [3, 6],
#   'Mobile Programming II': [1, 4, 6],
#   'IoT Architecture & Protocols/IoT Programming': [2, 3, 4, 5]}}

# %%
def main(display_dfs:bool= False):
    table = schedule()
    table.halls = [101, 115, 208, 209, 210, 303, 325, 326, 327, 329]
    table.courses= sorted(list(data['available_days'].keys()))
    table.available_days = data['available_days']
    table.professors = data['dr']
    table.departments = data['dep']
    table.course_hours = courses_hours
    
    table.create_variables()
    
    table.constrain_days()
    table.only_slot()
    table.add_no_overlap_constraints()
    table.constrain_pro()
    table.constrain_departments()
    table.objective_function(100,10)

    table.problem.solve()
    if 1 == table.problem.status and display_dfs: 
        print("dataframe is ready")
        for i in table.solution_to_dataframe():
            display(HTML(i.to_html(escape=False))) 
        
    else:
        print("No valid schedule found",table.problem.status)
    return table.solution_to_dataframe()

# %%
dfs = main(True)
# Out:
# dataframe is ready
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>1</th>
#       <th>2</th>
#       <th>3</th>
#       <th>4</th>
#       <th>5</th>
#       <th>6</th>
#       <th>7</th>
#       <th>8</th>
#     </tr>
#     <tr>
#       <th>Day/Hour - 1</th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>1</th>
#       <td>Physics (303) - Dr. Sarah Martinez</td>
#       <td>Technical English 1 (208) - Dr. Emily Wong</td>
#       <td>Intro. to Cyber Security (208) - Dr. Alicia Chen</td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td></td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>IT Essentials (115) - Dr. Marcus Johnson</td>
#       <td></td>
#       <td>Programming Essentials in Python (115) - Dr. David Lee</td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td></td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>Mathematics 1 (101) - Dr. Robert Taylor</td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td></td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td></td>
#     </tr>
#     <tr>
#       <th>5</th>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td></td>
#     </tr>
#   </tbody>
# </table>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>1</th>
#       <th>2</th>
#       <th>3</th>
#       <th>4</th>
#       <th>5</th>
#       <th>6</th>
#       <th>7</th>
#       <th>8</th>
#     </tr>
#     <tr>
#       <th>Day/Hour - 2</th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>1</th>
#       <td>Linux Essentials (115) - Dr. Thomas Wilson</td>
#       <td>Operating System (209) - Dr. Thomas Wilson</td>
#       <td>Digital Engineering (115) - Dr. James White</td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td></td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>Introduction to DB (209) - Dr. Jennifer Lopez</td>
#       <td>Programming Essentials in C++ (208) - Dr. David Lee</td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td></td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td></td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td></td>
#       <td>Web Programming I (101) - Dr. Rachel Green</td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td></td>
#     </tr>
#     <tr>
#       <th>5</th>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td></td>
#     </tr>
#   </tbody>
# </table>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>1</th>
#       <th>2</th>
#       <th>3</th>
#       <th>4</th>
#       <th>5</th>
#       <th>6</th>
#       <th>7</th>
#       <th>8</th>
#     </tr>
#     <tr>
#       <th>Day/Hour - 3s</th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>1</th>
#       <td>Microprocessor (209) - Dr. James White</td>
#       <td>Computer Architecture (101) - Dr. James White</td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td></td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>Advanced Programming in C (101) - Dr. David Lee</td>
#       <td>Data Communication (115) - Dr. Christopher Davis</td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td></td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>Computer Graphics (115) - Dr. Olivia Clark</td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td></td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>Java Programming II (115) - Dr. Rachel Green</td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td></td>
#     </tr>
#     <tr>
#       <th>5</th>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td></td>
#     </tr>
#   </tbody>
# </table>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>1</th>
#       <th>2</th>
#       <th>3</th>
#       <th>4</th>
#       <th>5</th>
#       <th>6</th>
#       <th>7</th>
#       <th>8</th>
#     </tr>
#     <tr>
#       <th>Day/Hour - 3n</th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>1</th>
#       <td>Microprocessor (209) - Dr. James White</td>
#       <td>Computer Architecture (101) - Dr. James White</td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td></td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>Network Administration (210) - Dr. Christopher Davis</td>
#       <td>Data Communication (115) - Dr. Christopher Davis</td>
#       <td>CCNA R&S II (101) - Dr. Christopher Davis</td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td></td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td></td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>Java Programming II (115) - Dr. Rachel Green</td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td></td>
#     </tr>
#     <tr>
#       <th>5</th>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td></td>
#     </tr>
#   </tbody>
# </table>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>1</th>
#       <th>2</th>
#       <th>3</th>
#       <th>4</th>
#       <th>5</th>
#       <th>6</th>
#       <th>7</th>
#       <th>8</th>
#     </tr>
#     <tr>
#       <th>Day/Hour - 4s</th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>1</th>
#       <td>Mobile Programming II (208) - Dr. Lisa Anderson</td>
#       <td>Signal Processing (329) - Dr. Sarah Martinez</td>
#       <td>Artificial Intelligence (101) - Dr. Sarah Martinez</td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td></td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>IoT Architecture & Protocols/IoT Programming (208) - Dr. Michael Brown</td>
#       <td>Windows Programming I (101) - Dr. Marcus Johnson</td>
#       <td>CCNA R&S II (101) - Dr. Christopher Davis</td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td></td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td></td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td></td>
#     </tr>
#     <tr>
#       <th>5</th>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td></td>
#     </tr>
#   </tbody>
# </table>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>1</th>
#       <th>2</th>
#       <th>3</th>
#       <th>4</th>
#       <th>5</th>
#       <th>6</th>
#       <th>7</th>
#       <th>8</th>
#     </tr>
#     <tr>
#       <th>Day/Hour - 4n</th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>1</th>
#       <td>CCNA Cybersecurity Operations (210) - Dr. Alicia Chen</td>
#       <td>Encryption Algorithm (115) - Dr. Alicia Chen</td>
#       <td>Artificial Intelligence (101) - Dr. Sarah Martinez</td>
#       <td>Server Administration (101) - Dr. Thomas Wilson</td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td></td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>IoT Architecture & Protocols/IoT Programming (208) - Dr. Michael Brown</td>
#       <td></td>
#       <td></td>
#       <td>CCNA R&S IV (101) - Dr. Christopher Davis</td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td></td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td></td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td></td>
#     </tr>
#     <tr>
#       <th>5</th>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td></td>
#     </tr>
#   </tbody>
# </table>

# %%
dfs[0]
# Out:
#                                                      1  \
# Day/Hour - 1
# 1                   Physics (303) - Dr. Sarah Martinez
# 2             IT Essentials (115) - Dr. Marcus Johnson
# 3              Mathematics 1 (101) - Dr. Robert Taylor
# 4
# 5
#
#                                                        2  \
# Day/Hour - 1
# 1             Technical English 1 (208) - Dr. Emily Wong
# 2
# 3
# 4
# 5
#
#                                                               3 4 5 6 7 8
# Day/Hour - 1
# 1              Intro. to Cyber Security (208) - Dr. Alicia Chen
# 2             Programming Essentials in Python (115) - Dr. D...
# 3
# 4
# 5
